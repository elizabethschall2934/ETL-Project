# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine
import json
from pandas.io.json import json_normalize
import os
import csv
from pprint import pprint

# %%
CA_sub=[]
GB_sub=[]
US_sub=[]

# %%
CA_file="CA_category_id.json"
GB_file="GB_category_id.json"
US_file="US_category_id.json"
type(US_file)
# Out:
# str

# %%
CA_json=pd.read_json(CA_file)
CA_json.head()
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 1  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 2  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 3  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 4  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"ld...

# %%
GB_json=pd.read_json(GB_file)
GB_json.head()
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %%
US_json=pd.read_json(US_file)
US_json.head()
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/S730Ilt-Fi-emsQJv...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"m2...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"m2...

# %%
for x in CA_json['items']:
        CA_sub.append([x['id'],x['snippet']['title']])
            
CA_sub
# Out:
# [['1', 'Film & Animation'],
#  ['2', 'Autos & Vehicles'],
#  ['10', 'Music'],
#  ['15', 'Pets & Animals'],
#  ['17', 'Sports'],
#  ['18', 'Short Movies'],
#  ['19', 'Travel & Events'],
#  ['20', 'Gaming'],
#  ['21', 'Videoblogging'],
#  ['22', 'People & Blogs'],
#  ['23', 'Comedy'],
#  ['24', 'Entertainment'],
#  ['25', 'News & Politics'],
#  ['26', 'Howto & Style'],
#  ['27', 'Education'],
#  ['28', 'Science & Technology'],
#  ['30', 'Movies'],
#  ['31', 'Anime/Animation'],
#  ['32', 'Action/Adventure'],
#  ['33', 'Classics'],
#  ['34', 'Comedy'],
#  ['35', 'Documentary'],
#  ['36', 'Drama'],
#  ['37', 'Family'],
#  ['38', 'Foreign'],
#  ['39', 'Horror'],
#  ['40', 'Sci-Fi/Fantasy'],
#  ['41', 'Thriller'],
#  ['42', 'Shorts'],
#  ['43', 'Shows'],
#  ['44', 'Trailers']]

# %%
for x in GB_json['items']:
        GB_sub.append([x['id'],x['snippet']['title']])
            
GB_sub
# Out:
# [['1', 'Film & Animation'],
#  ['2', 'Autos & Vehicles'],
#  ['10', 'Music'],
#  ['15', 'Pets & Animals'],
#  ['17', 'Sports'],
#  ['18', 'Short Movies'],
#  ['19', 'Travel & Events'],
#  ['20', 'Gaming'],
#  ['21', 'Videoblogging'],
#  ['22', 'People & Blogs'],
#  ['23', 'Comedy'],
#  ['24', 'Entertainment'],
#  ['25', 'News & Politics'],
#  ['26', 'Howto & Style'],
#  ['27', 'Education'],
#  ['28', 'Science & Technology'],
#  ['30', 'Movies'],
#  ['31', 'Anime/Animation'],
#  ['32', 'Action/Adventure'],
#  ['33', 'Classics'],
#  ['34', 'Comedy'],
#  ['35', 'Documentary'],
#  ['36', 'Drama'],
#  ['37', 'Family'],
#  ['38', 'Foreign'],
#  ['39', 'Horror'],
#  ['40', 'Sci-Fi/Fantasy'],
#  ['41', 'Thriller'],
#  ['42', 'Shorts'],
#  ['43', 'Shows'],
#  ['44', 'Trailers']]

# %%
for x in US_json['items']:
        US_sub.append([x['id'],x['snippet']['title']])
            
US_sub
# Out:
# [['1', 'Film & Animation'],
#  ['2', 'Autos & Vehicles'],
#  ['10', 'Music'],
#  ['15', 'Pets & Animals'],
#  ['17', 'Sports'],
#  ['18', 'Short Movies'],
#  ['19', 'Travel & Events'],
#  ['20', 'Gaming'],
#  ['21', 'Videoblogging'],
#  ['22', 'People & Blogs'],
#  ['23', 'Comedy'],
#  ['24', 'Entertainment'],
#  ['25', 'News & Politics'],
#  ['26', 'Howto & Style'],
#  ['27', 'Education'],
#  ['28', 'Science & Technology'],
#  ['29', 'Nonprofits & Activism'],
#  ['30', 'Movies'],
#  ['31', 'Anime/Animation'],
#  ['32', 'Action/Adventure'],
#  ['33', 'Classics'],
#  ['34', 'Comedy'],
#  ['35', 'Documentary'],
#  ['36', 'Drama'],
#  ['37', 'Family'],
#  ['38', 'Foreign'],
#  ['39', 'Horror'],
#  ['40', 'Sci-Fi/Fantasy'],
#  ['41', 'Thriller'],
#  ['42', 'Shorts'],
#  ['43', 'Shows'],
#  ['44', 'Trailers']]

# %%
Category_json = pd.DataFrame.from_dict(US_sub)
Category_json.columns = ['category_id', 'category']

Category_json
# Out:
#    category_id               category
# 0            1       Film & Animation
# 1            2       Autos & Vehicles
# 2           10                  Music
# 3           15         Pets & Animals
# 4           17                 Sports
# 5           18           Short Movies
# 6           19        Travel & Events
# 7           20                 Gaming
# 8           21          Videoblogging
# 9           22         People & Blogs
# 10          23                 Comedy
# 11          24          Entertainment
# 12          25        News & Politics
# 13          26          Howto & Style
# 14          27              Education
# 15          28   Science & Technology
# 16          29  Nonprofits & Activism
# 17          30                 Movies
# 18          31        Anime/Animation
# 19          32       Action/Adventure
# 20          33               Classics
# 21          34                 Comedy
# 22          35            Documentary
# 23          36                  Drama
# ...

# %%
Category_json['category_id'] = pd.to_numeric(Category_json['category_id'])
Category_json
# Out:
#     category_id               category
# 0             1       Film & Animation
# 1             2       Autos & Vehicles
# 2            10                  Music
# 3            15         Pets & Animals
# 4            17                 Sports
# 5            18           Short Movies
# 6            19        Travel & Events
# 7            20                 Gaming
# 8            21          Videoblogging
# 9            22         People & Blogs
# 10           23                 Comedy
# 11           24          Entertainment
# 12           25        News & Politics
# 13           26          Howto & Style
# 14           27              Education
# 15           28   Science & Technology
# 16           29  Nonprofits & Activism
# 17           30                 Movies
# 18           31        Anime/Animation
# 19           32       Action/Adventure
# 20           33               Classics
# 21           34                 Comedy
# 22           35            Documentary
# ...

# %%
engine = create_engine('postgresql://postgres:Rooster#21@localhost:5432/youtube_trends')
Category_json.to_sql(name = 'Category_json', con=engine, if_exists = 'append', index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
CA_csvfile = "CAvideos.csv"
CA_csvdf = pd.read_csv(CA_csvfile)
CA_csvdf.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
GB_csvfile = "GBvideos.csv"
GB_csvdf = pd.read_csv(GB_csvfile)
GB_csvdf.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
US_csvfile = "USvideos.csv"
US_csvdf = pd.read_csv(US_csvfile)
US_csvdf.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
CA_clean = CA_csvdf[['video_id','trending_date','title','channel_title','category_id','publish_time','tags','views',
                     'likes','dislikes','comment_count']].copy()
CA_clean.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
GB_clean = GB_csvdf[['video_id','trending_date','title','channel_title','category_id','publish_time','tags','views',
                     'likes','dislikes','comment_count']].copy()
GB_clean.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
US_clean = US_csvdf[['video_id','trending_date','title','channel_title','category_id','publish_time','tags','views',
                     'likes','dislikes','comment_count']].copy()
US_clean.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
US_final = pd.merge(US_clean, Category_json, on="category_id")
US_final.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  0mlNzVSJrT0      17.14.11
# 2  STI2fI7sKMo      17.14.11
# 3  KODzih-pYlU      17.14.11
# 4  8mhTWqWlQzU      17.14.11
#
#                                                title       channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                               Me-O Cats Commercial             Nobrand
# 2  AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3  BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4      Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           22  2017-04-21T06:47:32.000Z
# 2           22  2017-11-11T15:00:03.000Z
# 3           22  2017-11-11T18:08:04.000Z
# 4           22  2017-11-11T01:19:33.000Z
#
#                                                 tags    views   likes  \
# ...

# %%
US_final['country']='US'
US_final
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      0mlNzVSJrT0      17.14.11
# 2      STI2fI7sKMo      17.14.11
# 3      KODzih-pYlU      17.14.11
# 4      8mhTWqWlQzU      17.14.11
# ...            ...           ...
# 40944  V6ElE2xs48c      18.02.06
# 40945  V6ElE2xs48c      18.03.06
# 40946  V6ElE2xs48c      18.04.06
# 40947  V6ElE2xs48c      18.05.06
# 40948  V6ElE2xs48c      18.06.06
#
#                                                    title       channel_title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                                   Me-O Cats Commercial             Nobrand
# 2      AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3      BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4          Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
# ...                                                  ...                 ...
# ...

# %%
CA_final = pd.merge(CA_clean, Category_json, on="category_id")
CA_final.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  2Vv-BfVoq4g      17.14.11
# 2  H1KBHFXm2Bg      17.14.11
# 3  7MxiQ4v0EnE      17.14.11
# 4  j67FgNEvyh8      17.14.11
#
#                                                title  channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé     EminemVEVO
# 1        Ed Sheeran - Perfect (Official Music Video)     Ed Sheeran
# 2    21 Savage - Bank Account (Official Music Video)      21 Savage
# 3  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...  Speed Records
# 4  Telefoon || Babbu Maan || Promo || Full Song 1...       Hey Yolo
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           10  2017-11-09T11:04:14.000Z
# 2           10  2017-11-10T19:00:02.000Z
# 3           10  2017-11-11T16:41:15.000Z
# 4           10  2017-11-12T04:24:34.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
GB_final = pd.merge(GB_clean, Category_json, on="category_id")
GB_final.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  MyEqfBkzESU      17.14.11
# 2  b4vTZx_AtHk      17.14.11
# 3  OWvCCu2t6Ts      17.14.11
# 4  9GqL1DSQDL0      17.14.11
#
#                                                title         channel_title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster            John Lewis
# 1                  EXTREME GOLDEN TAN TRANSFORMATION          John Maclean
# 2                   How To Dry a Shirt in 30 Seconds            HowToBasic
# 3  SO Much To Tell You | 32 Weeks Pregnant | MOTH...     Sprinkleofglitter
# 4  GET READY WITH ME + LILY! (we're so immature bye)  makeupbymichaelfinch
#
#    category_id              publish_time  \
# 0           26  2017-11-10T07:38:29.000Z
# 1           26  2017-11-10T20:40:44.000Z
# 2           26  2017-11-09T18:36:48.000Z
# 3           26  2017-11-10T16:59:50.000Z
# 4           26  2017-11-09T22:00:00.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
CA_final['country']='CA'
CA_final.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  2Vv-BfVoq4g      17.14.11
# 2  H1KBHFXm2Bg      17.14.11
# 3  7MxiQ4v0EnE      17.14.11
# 4  j67FgNEvyh8      17.14.11
#
#                                                title  channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé     EminemVEVO
# 1        Ed Sheeran - Perfect (Official Music Video)     Ed Sheeran
# 2    21 Savage - Bank Account (Official Music Video)      21 Savage
# 3  Daang ( Full Video ) | Mankirt Aulakh | Sukh S...  Speed Records
# 4  Telefoon || Babbu Maan || Promo || Full Song 1...       Hey Yolo
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           10  2017-11-09T11:04:14.000Z
# 2           10  2017-11-10T19:00:02.000Z
# 3           10  2017-11-11T16:41:15.000Z
# 4           10  2017-11-12T04:24:34.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
GB_final['country']='GB'
GB_final.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  MyEqfBkzESU      17.14.11
# 2  b4vTZx_AtHk      17.14.11
# 3  OWvCCu2t6Ts      17.14.11
# 4  9GqL1DSQDL0      17.14.11
#
#                                                title         channel_title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster            John Lewis
# 1                  EXTREME GOLDEN TAN TRANSFORMATION          John Maclean
# 2                   How To Dry a Shirt in 30 Seconds            HowToBasic
# 3  SO Much To Tell You | 32 Weeks Pregnant | MOTH...     Sprinkleofglitter
# 4  GET READY WITH ME + LILY! (we're so immature bye)  makeupbymichaelfinch
#
#    category_id              publish_time  \
# 0           26  2017-11-10T07:38:29.000Z
# 1           26  2017-11-10T20:40:44.000Z
# 2           26  2017-11-09T18:36:48.000Z
# 3           26  2017-11-10T16:59:50.000Z
# 4           26  2017-11-09T22:00:00.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
world_final = pd.concat([US_final, GB_final, CA_final])
world_final.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  0mlNzVSJrT0      17.14.11
# 2  STI2fI7sKMo      17.14.11
# 3  KODzih-pYlU      17.14.11
# 4  8mhTWqWlQzU      17.14.11
#
#                                                title       channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE        CaseyNeistat
# 1                               Me-O Cats Commercial             Nobrand
# 2  AFFAIRS, EX BOYFRIENDS, $18MILLION NET WORTH -...  Shawn Johnson East
# 3  BLIND(folded) CAKE DECORATING CONTEST (with Mo...        Grace Helbig
# 4      Wearing Online Dollar Store Makeup For A Week      Safiya Nygaard
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           22  2017-04-21T06:47:32.000Z
# 2           22  2017-11-11T15:00:03.000Z
# 3           22  2017-11-11T18:08:04.000Z
# 4           22  2017-11-11T01:19:33.000Z
#
#                                                 tags    views   likes  \
# ...

# %%
engine = create_engine('postgresql://postgres:Rooster#21@localhost:5432/youtube_trends')
Category_json.to_sql(name = 'Category_json', con=engine, if_exists = 'append', index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2338         try:
# -> 2339             return fn()
#    2340         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
#Failed attempt at df.map

# %%
US_category={1:'Film & Animation', 2:'Autos & Vehicles', 10:'Music', 15:'Pets & Animals', 17:'Sports', 18:'Short Movies',
             19:'Travel & Events', 20:'Gaming', 21: 'Videoblogging', 22:'People & Blogs', 23:'Comedy', 24:'Entertainment',
             25:'News & Politics', 26:'Howto & Style', 27:'Education', 28:'Science & Technology', 29:'Nonprofits & Activism',
             30:'Movies', 31:'Anime/Animation', 32:'Action/Adventure', 33:'Classics', 34:'Comedy', 35:'Documentary', 36:'Drama',
             37:'Family', 38:'Foreign', 39:'Horror', 40:'Sci-Fi/Fantasy', 41:'Thriller', 42:'Shorts', 43:'Shows', 44:'Trailers'}

US_clean['category_title']=US_clean['category_id'].map(US_category)

US_clean = US_clean[['video_id', 'trending_date', 'title','channel_title', 'category_id', 'category_title', 'publish_time',
                     'tags', 'views', 'likes', 'dislikes', 'comment_count']]
US_clean.head()

# %%
#Failed attempt at df.concat

# %%
US_clean = US_clean.insert(5,'category_title', object)

# %%
US_final = pd.concat([US_clean, Category_json], join="outer", ignore_index=True)
US_final

# %%
US_final.to_csv('out.csv', index=False)
